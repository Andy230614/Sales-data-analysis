# %%
import pandas as pd

df= pd.read_csv("../Data/sales_data.csv", encoding='ISO-8859-1')

df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %% [markdown]
# What is the total sales?

# %%
print(df['Sales'].sum())
# Out:
# 2297200.8603
